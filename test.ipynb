# %%
file=open("readme.txt",'r')
content=file.read()
print(content)
# Out:
# Hello how are you. Welcome to Social Eagle AI Course

# %%
file=open("readme.txt",'w')
content=file.write('Today is my third day - content changed')
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
file=open("readme.txt",'a')
file.write('\n New content Appended')
file.write('\n Third Line\n')
file.close()

# %%
with open("readme.txt", "r") as file:
    content=file.read()
    print(content)
# Out:
# Today is my third day - content changed
#  New content Appended
#  New content Appended
#  Third Line

# %%
import os
os.getcwd()
os.mkdir("test")

# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['fazul', 'readme.txt', 'test', 'test.ipynb', 'test.py']
